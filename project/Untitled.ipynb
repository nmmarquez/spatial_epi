# %%
n <- 7
I <-matrix(0, 7, 7)
diag(I) <- 1
one <- 1:n / 1:n
B <- I - (one %*% t(one) / n)

# %%
one <- 1:n / 1:n

# %%
B <- I - (one %*% t(one) / n)

# %%
one %*% t(one) / n
# Out:
#           [,1]      [,2]      [,3]      [,4]      [,5]      [,6]      [,7]
# [1,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
# [2,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
# [3,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
# [4,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
# [5,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
# [6,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
# [7,] 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571 0.1428571
